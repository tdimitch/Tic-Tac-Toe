# %%
# Two player Tic Tac Toe game in Python.


''' We will make the board using dictionary in which 
    keys ('1' to '9') will be the location(i.e : top-left,mid-right,etc.).
    theBoard is initialized with empty spaces and updated with players' moves. '''

theBoard = {'1': ' ' , '2': ' ' , '3': ' ' ,
            '4': ' ' , '5': ' ' , '6': ' ' ,
            '7': ' ' , '8': ' ' , '9': ' ' }


    
''' We will have to print the updated board after every move in the game and 
    thus we will make a function in which we'll define the printBoard function
    so that we can easily print the board everytime by calling this function. '''
 
def printBoard(board):
    print('   |   |')
    print(' ' + board['1'] + ' | ' + board['2'] + ' | ' + board['3'])
    print('   |   |')
    print('-----------')
    print('   |   |')
    print(' ' + board['4'] + ' | ' + board['5'] + ' | ' + board['6'])
    print('   |   |')
    print('-----------')
    print('   |   |')
    print(' ' + board['7'] + ' | ' + board['8'] + ' | ' + board['9'])
    print('   |   |')


''' A function to check if a player has won. '''

def checkWin(board):
    # We define the boolean conditions to win
    a1 = board['1'] == board['2'] == board['3'] != ' ' # top row
    a2 = board['4'] == board['5'] == board['6'] != ' ' # middle row
    a3 = board['7'] == board['8'] == board['9'] != ' ' # bottom row
    a4 = board['1'] == board['4'] == board['7'] != ' ' # left column
    a5 = board['2'] == board['5'] == board['8'] != ' ' # middle column
    a6 = board['3'] == board['6'] == board['9'] != ' ' # right column
    a7 = board['1'] == board['5'] == board['9'] != ' ' # diagonal from up-left
    a8 = board['7'] == board['5'] == board['3'] != ' ' # diagonal from down-left
    
    # If any of the winning conditions is verified, return True
    if a1 or a2 or a3 or a4 or a5 or a6 or a7 or a8:
        return True

    
    
''' The main function game has all the gameplay functionality. '''

def game():

    turn = 'X'
    move_counter = 0
    
    while move_counter <= 9:
        printBoard(theBoard)
        print("\nIt's your turn, player " + turn + ". Choose a move: ")

        move = input()        

        if theBoard[move] == ' ':
            theBoard[move] = turn
            move_counter += 1
        else:
            print("That place is already filled. Choose a valid move. ")
            continue
        
        # If the number of moves is >= 5, check if the player has won.
        if move_counter >= 5 and checkWin(theBoard) == True:
            printBoard(theBoard)
            print("\nGame Over.\n **** Player " + turn + " won! ****")
            break

        # If neither X nor O wins and the board is full, we'll declare the result as 'tie'.
        if move_counter >= 9 and all(key != ' ' for key in theBoard):
            printBoard(theBoard)
            print("\nGame Over. It's a Tie!")
            break
        
        # Now we have to change the player after every move.
        if turn =='X':
            turn = 'O'
        else:
            turn = 'X'        
    
    # Now we will ask if player wants to restart the game or not. If so, we initialize theBoard.
    restart = input("Do want to play again? (y/n): ")
    if restart == "y" or restart == "Y":  
        for key in theBoard:
            theBoard[key] = " "
        print("\n\n")
        game()

game()
# Out:
#    |   |
#    |   |
#    |   |
# -----------
#    |   |
#    |   |
#    |   |
# -----------
#    |   |
#    |   |
#    |   |
#
# It's your turn, player X. Choose a move:
# 1
#    |   |
#  X |   |
#    |   |
# -----------
#    |   |
#    |   |
#    |   |
# -----------
#    |   |
#    |   |
#    |   |
#
# It's your turn, player O. Choose a move:
# 2
#    |   |
#  X | O |
#    |   |
# -----------
#    |   |
#    |   |
#    |   |
# -----------
#    |   |
#    |   |
#    |   |
#
# It's your turn, player X. Choose a move:
# 4
#    |   |
#  X | O |
#    |   |
# -----------
#    |   |
#  X |   |
#    |   |
# -----------
#    |   |
#    |   |
#    |   |
#
# It's your turn, player O. Choose a move:
# 5
#    |   |
#  X | O |
#    |   |
# -----------
#    |   |
#  X | O |
#    |   |
# -----------
#    |   |
#    |   |
#    |   |
#
# It's your turn, player X. Choose a move:
# 7
#    |   |
#  X | O |
#    |   |
# -----------
#    |   |
#  X | O |
#    |   |
# -----------
#    |   |
#  X |   |
#    |   |
#
# Game Over.
#  **** Player X won! ****
# Do want to play again? (y/n): n
